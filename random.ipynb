# %% [markdown]
# # Descrizione del problema
# Il problema riguarda lo **scheduling**. Sono dati $G$ ingegneri che lavorono per $L$ giorni. La realtà è composta da 3 elementi:
# * **Features**: sono le funzionalità implementate nei prodotti;
# * **Services**: sono i programmi che sono in esecuzione sui server;
# * **Binaries**: modellano un server. Ogni *binary* può avere in esecuzione più servizi;
#
# ## Relazioni tra le entità
# Una **Feature** è contraddistinta dal numero di utenti che riesce a soddisfare e da un insieme di servizi in cui deve essere implementata. Una **Feature** è disponibile ai clienti quando viene implementata in ogni servizio da cui dipende.
# Un **Service** è presente su **uno e un solo binary**, ma su ogni **binary** è possibile inserire più **Services**.

# %% [markdown]
# ### Lettura input da file
# Come prima cosa vengono letti i dati input e si effettua il parsing della prima riga per avere la dimensione del problema.

# %%
fname = "data/f.txt"

# lettura dei dati dal file di input
with open(fname, "r") as f:
    lines = f.readlines()
    
# parsing della prima riga: dimensione del problema
L, G, S, B, F, N = [int(k) for k in lines[0].strip().split(" ")]

# %%
# modellazione del sistema
from dataclasses import dataclass
from typing import List, Tuple, Dict, Set

score: int = 0
daily_schedule: List[Tuple[int, int]] = [] # giorno, binary

@dataclass
class Binary:
    id: int
    services: List[str]
    working_on: int
    locked: bool
binaries: List[Binary] =  [None] * B
service_to_binaries: Dict[str, int] = {}

@dataclass
class Service:
    name: str
    binary: int
    impl_features: List[str]

services: List[Service] = []

@dataclass
class Feature:
    idx: int
    name: str
    difficulty: int
    users: int
    dep_services: List[List]
    completed: bool
    binaries: Set[int]
    def populate_binaries(self):
        for (service, done) in self.dep_services:
            b = service_to_binaries[service]
            self.binaries.add(b)


features: List[Feature] = []

@dataclass
class Engineer:
    id: int
    avail: int
    ops: List[Tuple[str, List]]

    def add_op(self, op_name: str, day: str, duration: int, values: List[int]):
        if day > self.avail:
            self.ops.append(("wait", [day - self.avail]))

        affected_binaries = []
        if op_name == "move":
            service = services[values[0]]
            b1 = service_to_binaries[service.name]
            affected_binaries.append(b1, values[1])
        elif op_name == "impl":
            affected_binaries.append(values[1])
        elif op_name not in ["new", "wait"]:
            raise Exception(f"operation {op_name} not supported")

        # controllo se un binary coinvolto nell'operazione è bloccato
        # se si aggiungo una wait pari al massimo di quelli schedulati
        locked = [b for b in affected_binaries if binaries[b].locked]
        skip = []
        for l in locked:
            for ds in daily_schedule:
                if daily_schedule[ds] == l:
                    skip.append(ds)
        else:
            if len(skip) > 0:
                self.ops.append("wait", [day + skip])

        self.avail += day + duration
        self.ops.append((op_name, values))
engineers: List[Engineer] = []

# %% [markdown]
# ### Parsing dell'input
# In questa sezione, viene effettuato il parsing dei dati in ingresso creando:
# * Lista dei binary: tutti i binary del sistema; per ogni binary si tiene traccia della list dei service installati e del numero di ingegneri che lavora al momento;
# * Lista dei service; tutti i service del sistema. Per ogni service si tiene conto delle feature implementate al momento;
# * Lista delle feature: tutte le feature del sistema. Ogni feature contiene una lista coppie (stringhe, booleani) in cui si tiene conto dei servizi da implementare e del loro stato (implementato si/no);

# %%
for i in range(G):
    engineers.append(Engineer(i, 0, []))

for (service, binary) in [line.strip().split() for line in lines[1:S+1]]:
    bid = int(binary)
    b = binaries[bid]
    if b is None:
        b = Binary(bid, [service], 0, False)
        binaries[bid] = b
    else:
        b.services.append(service)

    s = Service(service, bid, [])
    services.append(s)
    service_to_binaries[service] = bid
idx = 0
for i, feature in enumerate(lines[1+S:]):
    # leggo solo le righe pari
    if i % 2 ==0:
        feature, num_services, difficulty, users = feature.strip().split(" ")
        s = [[s, False] for s in lines[1+S+1+i].split()]
        f = Feature(idx, feature, int(difficulty), int(users), s, False, set())
        f.populate_binaries()
        features.append(f)
        idx += 1

print(engineers, binaries, service_to_binaries, features, services, sep="\n")
# Out:
# [Engineer(id=0, avail=0, ops=[]), Engineer(id=1, avail=0, ops=[]), Engineer(id=2, avail=0, ops=[]), Engineer(id=3, avail=0, ops=[]), Engineer(id=4, avail=0, ops=[]), Engineer(id=5, avail=0, ops=[]), Engineer(id=6, avail=0, ops=[]), Engineer(id=7, avail=0, ops=[]), Engineer(id=8, avail=0, ops=[]), Engineer(id=9, avail=0, ops=[])]
# [Binary(id=0, services=['sb', 'sbd', 'sbf', 'scc', 'scf', 'sea', 'seb', 'sfi', 'sjg'], working_on=0, locked=False), Binary(id=1, services=['si', 'sbj', 'sci', 'sdb', 'sdi', 'sfg', 'shh', 'sib', 'sid', 'sij'], working_on=0, locked=False), Binary(id=2, services=['sbb', 'scg', 'sdh', 'sec', 'sef', 'seg', 'sfc', 'sgh', 'shi', 'sia', 'sji'], working_on=0, locked=False), Binary(id=3, services=['sh', 'sj', 'sbg', 'sdc', 'sfa', 'sfe', 'sfh', 'sga', 'sgf', 'shg'], working_on=0, locked=False), Binary(id=4, services=['sa', 'sdd', 'sdf', 'sgj', 'sha', 'shj', 'sie', 'sjd'], working_on=0, locked=False), Binary(id=5, services=['se', 'sbc', 'scb', 'sch', 'sdg', 'sej', 'sff', 'sgi', 'shb', 'shc', 'sic', 'sih', 'sjj'], working_on=0, locked=False), Binary(id=6, services=['sd', 'sba', 'sbe', 'sdj', 'see', 'sgc', 'sgg', 'sjb', 'sjc', 'sje'], working_on=0, locked=False), Binary(id=7, services=['scd', 'scj', 'sde', 'sed', 'sei', 'sfj', 'sgd', 'shd', 'shf', 'sif', 'sig', 'sii'], working_on=0, locked=False), Binary(id=8, services=['sf', 'sg', 'sbh', 'sce', 'sda', 'seh', 'sfb', 'sgb', 'she', 'sjf'], working_on=0, locked=False), Binary(id=9, services=['sc', 'sbi', 'sca', 'sfd', 'sge', 'sja', 'sjh'], working_on=0, locked=False)]
# {'sa': 4, 'sb': 0, 'sc': 9, 'sd': 6, 'se': 5, 'sf': 8, 'sg': 8, 'sh': 3, 'si': 1, 'sj': 3, 'sba': 6, 'sbb': 2, 'sbc': 5, 'sbd': 0, 'sbe': 6, 'sbf': 0, 'sbg': 3, 'sbh': 8, 'sbi': 9, 'sbj': 1, 'sca': 9, 'scb': 5, 'scc': 0, 'scd': 7, 'sce': 8, 'scf': 0, 'scg': 2, 'sch': 5, 'sci': 1, 'scj': 7, 'sda': 8, 'sdb': 1, 'sdc': 3, 'sdd': 4, 'sde': 7, 'sdf': 4, 'sdg': 5, 'sdh': 2, 'sdi': 1, 'sdj': 6, 'sea': 0, 'seb': 0, 'sec': 2, 'sed': 7, 'see': 6, 'sef': 2, 'seg': 2, 'seh': 8, 'sei': 7, 'sej': 5, 'sfa': 3, 'sfb': 8, 'sfc': 2, 'sfd': 9, 'sfe': 3, 'sff': 5, 'sfg': 1, 'sfh': 3, 'sfi': 0, 'sfj': 7, 'sga': 3, 'sgb': 8, 'sgc': 6, 'sgd': 7, 'sge': 9, 'sgf': 3, 'sgg': 6, 'sgh': 2, 'sgi': 5, 'sgj': 4, 'sha': 4, 'shb': 5, 'shc': 5, 'shd': 7, 'she': 8, 'shf': 7, 'shg': 3, 'shh': 1, 'shi': 2, 'shj': 4, 'sia': 2, 'sib': 1, 'sic': 5, 'sid': 1, 'sie': 4, 'sif': 7, 'sig': 7, 'sih': 5, 'sii': 7, 'sij': 1, 'sja': 9, 'sjb': 6, 'sjc': 6, 'sjd': 4, 'sje': 6, 'sjf': 8, 'sjg': 0, 'sjh': 9, 'sji': 2, 'sjj': 5}
# [Feature(idx=0, name='sfbgdbdf', difficulty=46, users=425, dep_services=[['sbi', False]], completed=False, binaries={9}), Feature(idx=1, name='sjhbhfhe', difficulty=99, users=854, dep_services=[['sga', False], ['shi', False], ['shb', False]], completed=False, binaries={2, 3, 5}), Feature(idx=2, name='sebdcfig', difficulty=6, users=658, dep_services=[['sec', False], ['sg', False], ['sig', False]], completed=False, binaries={8, 2, 7}), Feature(idx=3, name='sgbihbfd', difficulty=51, users=830, dep_services=[['sha', False], ['sgc', False], ['sef', False], ['sjj', False]], completed=False, binaries={2, 4, 5, 6}), Feature(idx=4, name='scgdhghe', difficulty=61, users=843, dep_services=[['sih', False], ['sbg', False], ['sbb', False]], completed=False, binaries={2, 3, 5}), Feature(idx=5, name='sbhabcbe', difficulty=32, users=737, dep_services=[['shg', False], ['sbc', False]], completed=False, binaries={3, 5}), Feature(idx=6, name='scdbaagh', difficulty=52, users=176, dep_services=[['sha', False], ['sa', False]], completed=False, binaries={4}), Feature(idx=7, name='siiaeejh', difficulty=49, users=999, dep_services=[['sga', False], ['sij', False]], completed=False, binaries={1, 3}), Feature(idx=8, name='sgdhfghj', difficulty=43, users=532, dep_services=[['sje', False], ['shc', False]], completed=False, binaries={5, 6}), Feature(idx=9, name='sgjhcbib', difficulty=83, users=719, dep_services=[['sjh', False], ['si', False]], completed=False, binaries={9, 1}), Feature(idx=10, name='sdcegeje', difficulty=57, users=773, dep_services=[['sfi', False]], completed=False, binaries={0}), Feature(idx=11, name='sigefibb', difficulty=65, users=817, dep_services=[['sjf', False], ['sib', False]], completed=False, binaries={8, 1}), Feature(idx=12, name='sceafihh', difficulty=91, users=843, dep_services=[['sie', False], ['sbb', False], ['sdg', False]], completed=False, binaries={2, 4, 5}), Feature(idx=13, name='sfhdcbde', difficulty=30, users=589, dep_services=[['sjd', False], ['sie', False]], completed=False, binaries={4}), Feature(idx=14, name='sfeggidi', difficulty=50, users=806, dep_services=[['sdh', False], ['sdb', False], ['sfg', False]], completed=False, binaries={1, 2}), Feature(idx=15, name='sjjiifji', difficulty=36, users=621, dep_services=[['sdh', False]], completed=False, binaries={2}), Feature(idx=16, name='scifaejh', difficulty=87, users=677, dep_services=[['seh', False], ['sha', False]], completed=False, binaries={8, 4}), Feature(idx=17, name='sfbdgadf', difficulty=37, users=128, dep_services=[['sbj', False], ['sji', False], ['sfd', False], ['shi', False]], completed=False, binaries={1, 2, 9}), Feature(idx=18, name='sjdffaae', difficulty=97, users=983, dep_services=[['sjb', False], ['scj', False]], completed=False, binaries={6, 7}), Feature(idx=19, name='sjjcbagi', difficulty=47, users=519, dep_services=[['sff', False], ['sb', False], ['sdj', False]], completed=False, binaries={0, 5, 6}), Feature(idx=20, name='sfidfhhh', difficulty=44, users=106, dep_services=[['se', False], ['sfd', False]], completed=False, binaries={9, 5}), Feature(idx=21, name='sdfbbdgf', difficulty=67, users=355, dep_services=[['sa', False], ['shi', False], ['sea', False]], completed=False, binaries={0, 2, 4}), Feature(idx=22, name='sfahfihb', difficulty=14, users=833, dep_services=[['si', False], ['sed', False], ['sec', False], ['sgg', False]], completed=False, binaries={1, 2, 6, 7}), Feature(idx=23, name='sgghccbc', difficulty=51, users=498, dep_services=[['sig', False], ['sii', False], ['sib', False]], completed=False, binaries={1, 7}), Feature(idx=24, name='seghcdfj', difficulty=68, users=485, dep_services=[['sgf', False], ['sca', False]], completed=False, binaries={9, 3}), Feature(idx=25, name='scgbbhdc', difficulty=92, users=202, dep_services=[['sgf', False], ['sjj', False]], completed=False, binaries={3, 5}), Feature(idx=26, name='sdcgagfg', difficulty=49, users=649, dep_services=[['sdg', False], ['sdc', False]], completed=False, binaries={3, 5}), Feature(idx=27,  ...
# [Service(name='sa', binary=4, impl_features=[]), Service(name='sb', binary=0, impl_features=[]), Service(name='sc', binary=9, impl_features=[]), Service(name='sd', binary=6, impl_features=[]), Service(name='se', binary=5, impl_features=[]), Service(name='sf', binary=8, impl_features=[]), Service(name='sg', binary=8, impl_features=[]), Service(name='sh', binary=3, impl_features=[]), Service(name='si', binary=1, impl_features=[]), Service(name='sj', binary=3, impl_features=[]), Service(name='sba', binary=6, impl_features=[]), Service(name='sbb', binary=2, impl_features=[]), Service(name='sbc', binary=5, impl_features=[]), Service(name='sbd', binary=0, impl_features=[]), Service(name='sbe', binary=6, impl_features=[]), Service(name='sbf', binary=0, impl_features=[]), Service(name='sbg', binary=3, impl_features=[]), Service(name='sbh', binary=8, impl_features=[]), Service(name='sbi', binary=9, impl_features=[]), Service(name='sbj', binary=1, impl_features=[]), Service(name='sca', binary=9, impl_features=[]), Service(name='scb', binary=5, impl_features=[]), Service(name='scc', binary=0, impl_features=[]), Service(name='scd', binary=7, impl_features=[]), Service(name='sce', binary=8, impl_features=[]), Service(name='scf', binary=0, impl_features=[]), Service(name='scg', binary=2, impl_features=[]), Service(name='sch', binary=5, impl_features=[]), Service(name='sci', binary=1, impl_features=[]), Service(name='scj', binary=7, impl_features=[]), Service(name='sda', binary=8, impl_features=[]), Service(name='sdb', binary=1, impl_features=[]), Service(name='sdc', binary=3, impl_features=[]), Service(name='sdd', binary=4, impl_features=[]), Service(name='sde', binary=7, impl_features=[]), Service(name='sdf', binary=4, impl_features=[]), Service(name='sdg', binary=5, impl_features=[]), Service(name='sdh', binary=2, impl_features=[]), Service(name='sdi', binary=1, impl_features=[]), Service(name='sdj', binary=6, impl_features=[]), Service(name='sea', binary=0, impl_features=[]), Service(name='seb', binary=0, impl_features=[]), Service(name='sec', binary=2, impl_features=[]), Service(name='sed', binary=7, impl_features=[]), Service(name='see', binary=6, impl_features=[]), Service(name='sef', binary=2, impl_features=[]), Service(name='seg', binary=2, impl_features=[]), Service(name='seh', binary=8, impl_features=[]), Service(name='sei', binary=7, impl_features=[]), Service(name='sej', binary=5, impl_features=[]), Service(name='sfa', binary=3, impl_features=[]), Service(name='sfb', binary=8, impl_features=[]), Service(name='sfc', binary=2, impl_features=[]), Service(name='sfd', binary=9, impl_features=[]), Service(name='sfe', binary=3, impl_features=[]), Service(name='sff', binary=5, impl_features=[]), Service(name='sfg', binary=1, impl_features=[]), Service(name='sfh', binary=3, impl_features=[]), Service(name='sfi', binary=0, impl_features=[]), Service(name='sfj', binary=7, impl_features=[]), Service(name='sga', binary=3, impl_features=[]), Service(name='sgb', binary=8, impl_features=[]), Service(name='sgc', binary=6, impl_features=[]), Service(name='sgd', binary=7, impl_features=[]), Service(name='sge', binary=9, impl_features=[]), Service(name='sgf', binary=3, impl_features=[]), Service(name='sgg', binary=6, impl_features=[]), Service(name='sgh', binary=2, impl_features=[]), Service(name='sgi', binary=5, impl_features=[]), Service(name='sgj', binary=4, impl_features=[]), Service(name='sha', binary=4, impl_features=[]), Service(name='shb', binary=5, impl_features=[]), Service(name='shc', binary=5, impl_features=[]), Service(name='shd', binary=7, impl_features=[]), Service(name='she', binary=8, impl_features=[]), Service(name='shf', binary=7, impl_features=[]), Service(name='shg', binary=3, impl_features=[]), Service(name='shh', binary=1, impl_features=[]), Service(name='shi', binary=2, impl_features=[]), Service(name='shj', binary=4, impl_features=[]), Service(name='sia', binary=2, impl_features=[]), Service(name='sib', binary=1, impl_featu ...

# %% [markdown]
# ## Attività
# Di seguito sono illustrate le mosse che un ingegnere può effettuare.
#
# Ciascuna mossa è caratterizzata da una durata. Per ogni mossa è definita una procedura per eseguirla sui dati di input. Ogni procedura ha la seguente firma:
# * input:
#     * ingegnere su cui schedulare l'attività;
#     * giorno in cui effettuare l'attività;
#     * feature, binary, service su cui effettuare l'attività;
# * output:
#     * durata dell'attività;

# %% [markdown]
# ### Implementazione di una nuova feature
# Su un *binary* $B_j$ può un ingegnere implementare tutti i servizi per una feature $F_i$. Questa mossa ha una durata $D_{Fi} + R_{Bj} + C_{Bj}$. Dove $D_{Fi}$ è data dalla complessità della **Feature**, $R_{Bj}$ è dato dal numero di servizi totali presenti nel *binary*, $C_{Bj}$ ingegneri che stanno già lavorando su $B_j$ nel giorno in cui viene *schedulata* l'attività. Inoltre, ogni ingegnere può implementare la stessa **Feature** su **binary** diversi. Infine, se più ingegneri sono *schedulati* per lavorare sullo stesso **binary** il primo della soluzione viene schedulato e conta per gli altri nel fattore $C_{Bj}$;

# %%
def implement_feature(e: int, day: int, f: int, b: int) -> int:
    assert(b >= 0 and b < B)
    assert(day >=0 and day < L)
    assert(f >= 0 and f < F)
    assert(e >= 0 and e < G)
    global score
    engineer = engineers[e]
    feature = features[f]
    
    duration  = feature.difficulty + len(binaries[b].services) + binaries[b].working_on
    for service in feature.dep_services:
        s_name = service[0]
        done = service[1]
        if service_to_binaries[s_name] == b and not done:
            service[1] = True
    
    for (service, done) in feature.dep_services:
        if not done:
            break
    else:
        if not feature.completed:
            feature.completed = True
            # print("DEBUG: completed", feature, "multiply", 1 if  L-(day + duration) >= 0 else 0  )
            # print("DEBUG: remaining", len(features))
            score += feature.users * max(0, L-(day + duration)) 
    engineer.add_op("impl", day, duration, [f, b])
    daily_schedule.append((day + duration, b))
    binaries[b].working_on+=1
    
    return duration

# %% [markdown]
# ### Migrazione di un service
# un ingegnere può spostare un servizio $S_i$ da un *binary* $B_j$ a $B_k$, mantenendo le funzionalità implementate. Per fare questa mossa, un ingegnere impiega $\max (R_{bj}, R_{bk})$ giorni dove $R_{bj}, R_{bk}$ sono i servizi in esecuzione rispettivamente su $B_j$ a $B_k$. Quest'azione però è bloccante: nessun ingegnere può lavorare su $B_j$ e $B_k$ quando è in corso una migrazione;

# %%
def move_service(e: Engineer, day: int, s: int, dst: int) -> int:
    assert(service_to_binaries[s] != dst)
    assert(day >= 0 and  day < L)
    assert(dst >= 0 and dst < B)
    service = services[s]
    src = service.binary
    duration  = max(len(binaries[src].services), len(binaries[dst].services))
    service_to_binaries[service.name] = dst
    binaries[src].services.remove(s)
    binaries[dst].services.append(s)
    binaries[src].locked = True
    binaries[dst].locked = True
    e.add_op("move", day, duration, [service.name, src, dst])
    return duration

# %% [markdown]
# ### Nuovo binary
# Un ingegnere può creare un nuovo binary senza nessun servizio al suo interno. Il costo per creare è un nuovo binary è fisso e vale $N$.

# %%
def new_binary(e: Engineer, day: int)-> int:
    assert(day >=0 and day < L)
    binaries.append(Binary(len(binaries)))
    e.add_op("new", day, N, [])
    return N

# %% [markdown]
# ### Idle
# Un ingegnere può essere in idle per un numero di giorni $1\leq W \leq L$

# %%
def wait(e: Engineer, day: int, duration: int) -> int:
    assert(day >=0 and day < L)
    e.add_op("wait", day, duration, [])
    return 1

# %% [markdown]
# ## Euristica
# In una fase preliminare, l'algoritmo ordina le feature per numero di utenti soddisfatti. In questo approccio, si assegna un punteggio maggiore ai servizi che risiedono sulla stessa macchina.

# %%
import random
for day in range(L):
    while len(daily_schedule) > 0 and daily_schedule[-1][0] <= day:
        # migrazione
        if len(daily_schedule[-1]) == 3:
            b1 = daily_schedule[-1][1]
            b2 = daily_schedule[-1][2]
            binaries[b1].locked = False 
            binaries[b2].locked = False 
        elif len(daily_schedule[-1]) == 2:
            bid: int = daily_schedule[-1][1] 
            binaries[bid].working_on -=1
        else:
            raise Exception("unknown schedule event", daily_schedule[-1])
        daily_schedule.pop()
    
    for engineer in engineers:
        if engineer.avail <= day:
          f: Feature = random.choice(features)
          b: Binary = random.choice(binaries)
          implement_feature(engineer.id, day, f.idx, b.id)

num_eng: int = len([engineer for engineer in engineers if len(engineer.ops) > 0])
print(num_eng)
for engineer in engineers:
    if len(engineer.ops) == 0:
        continue
    print(engineer.id)
    for op in engineer.ops:
        print(op[0], end=" ")
        if op[0] == "impl":
            f = features[op[1][0]]
            print(f.name, op[1][1])
        elif op[0] == "move":
            print(op[1][0], op[1][2])
        elif op[0] == "wait":
            print(op[0], op[1][0])

print(score)
# print("features", features)
# print("impl features:", impl_features)
# sus = [f.users for f in impl_features]
# print(sum(sus))
# record 158.421.404
# Out:
# 10
# 0
# impl segejigj 6
# impl siibaccd 0
# impl sfghddaf 3
# impl siibbjad 8
# impl shafdiig 5
# 1
# impl scgidbdb 1
# impl scdbbbgi 0
# impl sbjahidb 2
# impl sfdbhjac 1
# impl siahihh 8
# 2
# impl sheijggg 1
# impl sbdbjbjb 8
# impl shjajjdf 8
# impl sjbhhegj 1
# impl sbcagbag 3
# 3
# impl sbccgcbi 1
# impl sijahjbi 6
# impl sdfaafc 5
# impl sfjgicid 8
# 4
# impl siejbjh 7
# impl sfgcbaih 8
# impl sigjjdah 4
# impl sigdgjgg 7
# impl shjgigi 0
# 5
# impl seafbii 3
# impl seefaejg 3
# impl sbbdhagd 9
# impl sheifdbh 8
# 6
# impl sbcbahhd 4
# impl scccejdg 7
# impl scabadae 6
# impl sbdefiib 8
# 7
# impl sjccedai 2
# impl shjedacc 5
# impl siidfieh 2
# impl sjcjbbe 9
# impl sheiccjh 4
# 8
# impl sggghehd 7
# impl sdjeajgc 2
# impl sefegdgi 7
# impl sdaegiji 5
# impl shbdabib 0
# 9
# impl scgdhbde 3
# impl siigjci 4
# impl shahffji 9
# impl sghagdde 3
# impl scfchfch 2
# 0
