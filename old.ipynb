# %% [markdown]
# # Descrizione del problema
# Il problema riguarda lo **scheduling**. Sono dati $G$ ingegneri che lavorono per $L$ giorni. La realtà è composta da 3 elementi:
# * **Features**: sono le funzionalità implementate nei prodotti;
# * **Services**: sono i programmi che sono in esecuzione sui server;
# * **Binaries**: modellano un server. Ogni *binary* può avere in esecuzione più servizi;
#
# Una **Feature** è contraddistinta dal numero di utenti che riesce a soddisfare e da un insieme di servizi in cui deve essere implementata. Una **Feature** è disponibile ai clienti quando viene implementata in ogni servizio da cui dipende.
# Un **Service** è presente su **uno e un solo binary**, ma su ogni **binary** è possibile inserire più **Services**.
#
# Di seguito sono riportate le strutture utilizzate per modellare il problema.

# %%
from dataclasses import dataclass
from typing import List, Dict, Tuple

@dataclass
class Binary:
    id: int
    services: List[int]
    working_on: int
    last_move: int
    last_work: int

    def can_move(self, day: int) -> bool:
        return max(self.last_move, self.last_work) <= day

    def can_work(self, day: int) -> bool:
        return self.last_move <= day
    


binaries: List[Binary] =  []
service_to_binaries: Dict[str, int] = {}
service_to_id: Dict[str, int] = {}

@dataclass
class Service:
    id: int
    name: str
    binary: int
    impl_features: List[str]

services: List[Service] = []
@dataclass
class Feature:
    idx: int
    name: str
    difficulty: int
    users: int
    dep_services: List[List]
    day_completed: int
    
    def is_finished(self) -> bool:
        for (service, completed) in self.dep_services:
            if not completed:
                return False
        return True

features: List[Feature] = []

# %% [markdown]
# ## Strutture per lo scheduling
# Ogni ingegnere è dotato di un array di operazioni da effettuare che tenere traccia delle sue attività. In particolare, la classe `Engineer` espone il metodo `add_op` che aggiunge l'operazione per un determinato giorno se e solo se è libero (grazie alla proprietà `avail`), altrimenti viene inserita un'operazione di `wait` della durata necessaria.

# %%
@dataclass
class Engineer:
    id: int
    avail: int
    ops: List[Tuple[str, List[int]]]

    def add_op(self, op_name: str, day: int, duration: int, values: List[int]):
        assert(self.avail <= day)
        if self.avail < day:
            self.ops.append(("wait", [day - self.avail]))

        self.ops.append((op_name, values))
        self.avail = day + duration
        
engineers: List[Engineer] = []

# %% [markdown]
# ### Lettura input da file
# Come prima cosa vengono letti i dati input e si effettua il parsing della prima riga per avere la dimensione del problema.

# %%
fname = "data/e.in"

# lettura dei dati dal file di input
with open(fname, "r") as f:
    lines = f.readlines()
    
# parsing della prima riga: dimensione del problema
L, G, S, B, F, N = [int(k) for k in lines[0].strip().split(" ")]

# %%
# modellazione del sistema
from dataclasses import dataclass
from typing import List, Tuple, Dict, Set

score: int = 0
daily_schedule: List[Tuple[int, int]] = [] # giorno, binary

@dataclass
class Binary:
    id: int
    services: List[str]
    working_on: int
    locked: bool
binaries: List[Binary] =  [None] * B
service_to_binaries: Dict[str, int] = {}

@dataclass
class Service:
    name: str
    binary: int
    impl_features: List[str]

services: List[Service] = []

@dataclass
class Feature:
    idx: int
    name: str
    difficulty: int
    users: int
    dep_services: List[List]
    completed: bool
    binaries: Set[int]
    def populate_binaries(self):
        for (service, done) in self.dep_services:
            b = service_to_binaries[service]
            self.binaries.add(b)


features: List[Feature] = []

@dataclass
class Engineer:
    id: int
    avail: int
    ops: List[Tuple[str, List]]

    def add_op(self, op_name: str, day: str, duration: int, values: List[int]):
        if day > self.avail:
            self.ops.append(("wait", [day - self.avail]))

        affected_binaries = []
        if op_name == "move":
            service = services[values[0]]
            b1 = service_to_binaries[service.name]
            affected_binaries.append(b1, values[1])
        elif op_name == "impl":
            affected_binaries.append(values[1])
        elif op_name not in ["new", "wait"]:
            raise Exception(f"operation {op_name} not supported")

        # controllo se un binary coinvolto nell'operazione è bloccato
        # se si aggiungo una wait pari al massimo di quelli schedulati
        locked = [b for b in affected_binaries if binaries[b].locked]
        skip = []
        for l in locked:
            for ds in daily_schedule:
                if daily_schedule[ds] == l:
                    skip.append(ds)
        else:
            if len(skip) > 0:
                self.ops.append("wait", [day + skip])

        self.avail = day + duration
        self.ops.append((op_name, values))
engineers: List[Engineer] = []

# %% [markdown]
# ### Parsing dell'input
# In questa sezione, viene effettuato il parsing dei dati in ingresso creando:
# * Lista dei binary: tutti i binary del sistema; per ogni binary si tiene traccia della list dei service installati e del numero di ingegneri che lavora al momento;
# * Lista dei service; tutti i service del sistema. Per ogni service si tiene conto delle feature implementate al momento;
# * Lista delle feature: tutte le feature del sistema. Ogni feature contiene una lista coppie (stringhe, booleani) in cui si tiene conto dei servizi da implementare e del loro stato (implementato si/no);

# %%
for i in range(G):
    engineers.append(Engineer(i, 0, []))

for (service, binary) in [line.strip().split() for line in lines[1:S+1]]:
    bid = int(binary)
    b = binaries[bid]
    if b is None:
        b = Binary(bid, [service], 0, False)
        binaries[bid] = b
    else:
        b.services.append(service)

    s = Service(service, bid, [])
    services.append(s)
    service_to_binaries[service] = bid
idx = 0
for i, feature in enumerate(lines[1+S:]):
    # leggo solo le righe pari
    if i % 2 ==0:
        feature, num_services, difficulty, users = feature.strip().split(" ")
        s = [[s, False] for s in lines[1+S+1+i].split()]
        f = Feature(idx, feature, int(difficulty), int(users), s, False, set())
        f.populate_binaries()
        features.append(f)
        idx += 1

print(engineers, binaries, service_to_binaries, features, services, sep="\n")
# Out:
# [Engineer(id=0, avail=0, ops=[]), Engineer(id=1, avail=0, ops=[]), Engineer(id=2, avail=0, ops=[]), Engineer(id=3, avail=0, ops=[]), Engineer(id=4, avail=0, ops=[]), Engineer(id=5, avail=0, ops=[]), Engineer(id=6, avail=0, ops=[]), Engineer(id=7, avail=0, ops=[]), Engineer(id=8, avail=0, ops=[]), Engineer(id=9, avail=0, ops=[]), Engineer(id=10, avail=0, ops=[]), Engineer(id=11, avail=0, ops=[]), Engineer(id=12, avail=0, ops=[]), Engineer(id=13, avail=0, ops=[]), Engineer(id=14, avail=0, ops=[]), Engineer(id=15, avail=0, ops=[]), Engineer(id=16, avail=0, ops=[]), Engineer(id=17, avail=0, ops=[]), Engineer(id=18, avail=0, ops=[]), Engineer(id=19, avail=0, ops=[]), Engineer(id=20, avail=0, ops=[]), Engineer(id=21, avail=0, ops=[]), Engineer(id=22, avail=0, ops=[]), Engineer(id=23, avail=0, ops=[]), Engineer(id=24, avail=0, ops=[]), Engineer(id=25, avail=0, ops=[]), Engineer(id=26, avail=0, ops=[]), Engineer(id=27, avail=0, ops=[]), Engineer(id=28, avail=0, ops=[]), Engineer(id=29, avail=0, ops=[]), Engineer(id=30, avail=0, ops=[]), Engineer(id=31, avail=0, ops=[]), Engineer(id=32, avail=0, ops=[]), Engineer(id=33, avail=0, ops=[]), Engineer(id=34, avail=0, ops=[]), Engineer(id=35, avail=0, ops=[]), Engineer(id=36, avail=0, ops=[]), Engineer(id=37, avail=0, ops=[]), Engineer(id=38, avail=0, ops=[]), Engineer(id=39, avail=0, ops=[]), Engineer(id=40, avail=0, ops=[]), Engineer(id=41, avail=0, ops=[]), Engineer(id=42, avail=0, ops=[]), Engineer(id=43, avail=0, ops=[]), Engineer(id=44, avail=0, ops=[]), Engineer(id=45, avail=0, ops=[]), Engineer(id=46, avail=0, ops=[]), Engineer(id=47, avail=0, ops=[]), Engineer(id=48, avail=0, ops=[]), Engineer(id=49, avail=0, ops=[]), Engineer(id=50, avail=0, ops=[]), Engineer(id=51, avail=0, ops=[]), Engineer(id=52, avail=0, ops=[]), Engineer(id=53, avail=0, ops=[]), Engineer(id=54, avail=0, ops=[]), Engineer(id=55, avail=0, ops=[]), Engineer(id=56, avail=0, ops=[]), Engineer(id=57, avail=0, ops=[]), Engineer(id=58, avail=0, ops=[]), Engineer(id=59, avail=0, ops=[]), Engineer(id=60, avail=0, ops=[]), Engineer(id=61, avail=0, ops=[]), Engineer(id=62, avail=0, ops=[]), Engineer(id=63, avail=0, ops=[]), Engineer(id=64, avail=0, ops=[]), Engineer(id=65, avail=0, ops=[]), Engineer(id=66, avail=0, ops=[]), Engineer(id=67, avail=0, ops=[]), Engineer(id=68, avail=0, ops=[]), Engineer(id=69, avail=0, ops=[]), Engineer(id=70, avail=0, ops=[]), Engineer(id=71, avail=0, ops=[]), Engineer(id=72, avail=0, ops=[]), Engineer(id=73, avail=0, ops=[]), Engineer(id=74, avail=0, ops=[]), Engineer(id=75, avail=0, ops=[]), Engineer(id=76, avail=0, ops=[]), Engineer(id=77, avail=0, ops=[]), Engineer(id=78, avail=0, ops=[]), Engineer(id=79, avail=0, ops=[]), Engineer(id=80, avail=0, ops=[]), Engineer(id=81, avail=0, ops=[]), Engineer(id=82, avail=0, ops=[]), Engineer(id=83, avail=0, ops=[]), Engineer(id=84, avail=0, ops=[]), Engineer(id=85, avail=0, ops=[]), Engineer(id=86, avail=0, ops=[]), Engineer(id=87, avail=0, ops=[]), Engineer(id=88, avail=0, ops=[]), Engineer(id=89, avail=0, ops=[]), Engineer(id=90, avail=0, ops=[]), Engineer(id=91, avail=0, ops=[]), Engineer(id=92, avail=0, ops=[]), Engineer(id=93, avail=0, ops=[]), Engineer(id=94, avail=0, ops=[]), Engineer(id=95, avail=0, ops=[]), Engineer(id=96, avail=0, ops=[]), Engineer(id=97, avail=0, ops=[]), Engineer(id=98, avail=0, ops=[]), Engineer(id=99, avail=0, ops=[]), Engineer(id=100, avail=0, ops=[]), Engineer(id=101, avail=0, ops=[]), Engineer(id=102, avail=0, ops=[]), Engineer(id=103, avail=0, ops=[]), Engineer(id=104, avail=0, ops=[]), Engineer(id=105, avail=0, ops=[]), Engineer(id=106, avail=0, ops=[]), Engineer(id=107, avail=0, ops=[]), Engineer(id=108, avail=0, ops=[]), Engineer(id=109, avail=0, ops=[]), Engineer(id=110, avail=0, ops=[]), Engineer(id=111, avail=0, ops=[]), Engineer(id=112, avail=0, ops=[]), Engineer(id=113, avail=0, ops=[]), Engineer(id=114, avail=0, ops=[]), Engineer(id=115, avail=0, ops=[]), Engineer(id=116, avail=0, ops=[]), Engineer(id=11 ...
# [Binary(id=0, services=['sc', 'sd', 'se', 'sf', 'sh', 'sba', 'sbd', 'sbg', 'sbh', 'sbi', 'sbj', 'sca', 'scc', 'sce', 'scg', 'sch', 'sci', 'scj', 'sdc', 'sdd', 'sdf', 'sdg', 'sea', 'seb', 'sed', 'see', 'sef', 'seg', 'sfa', 'sfc', 'sgb', 'sgf', 'sgj', 'sha', 'shb', 'shc', 'shd', 'she', 'shh', 'shi', 'shj', 'sia', 'sid', 'sig', 'sih', 'sii', 'sij', 'sja', 'sjb', 'sjd', 'sbaa', 'sbab', 'sbad', 'sbae', 'sbaf', 'sbbb', 'sbbe', 'sbbg', 'sbca', 'sbcb', 'sbcg', 'sbch', 'sbci', 'sbda', 'sbdb', 'sbdc', 'sbdf', 'sbdg', 'sbdh', 'sbdi', 'sbdj', 'sbea', 'sbec', 'sbeh', 'sbei', 'sbej', 'sbfc', 'sbfd', 'sbfg', 'sbfh', 'sbfi', 'sbfj', 'sbgb', 'sbgc', 'sbgd', 'sbgh', 'sbha', 'sbhj', 'sbib', 'sbic', 'sbii', 'sbja', 'sbjb', 'sbjc', 'sbje', 'sbjg', 'sbjh', 'sbji', 'sbjj'], working_on=0, locked=False), Binary(id=1, services=['sa', 'sb', 'sg', 'si', 'sj', 'sbb', 'sbc', 'sbe', 'sbf', 'scb', 'scd', 'scf', 'sda', 'sdb', 'sde', 'sdh', 'sdi', 'sdj', 'sec', 'seh', 'sei', 'sej', 'sfb', 'sfd', 'sfe', 'sff', 'sfg', 'sfh', 'sfi', 'sfj', 'sga', 'sgc', 'sgd', 'sge', 'sgg', 'sgh', 'sgi', 'shf', 'shg', 'sib', 'sic', 'sie', 'sif', 'sjc', 'sje', 'sjf', 'sjg', 'sjh', 'sji', 'sjj', 'sbac', 'sbag', 'sbah', 'sbai', 'sbaj', 'sbba', 'sbbc', 'sbbd', 'sbbf', 'sbbh', 'sbbi', 'sbbj', 'sbcc', 'sbcd', 'sbce', 'sbcf', 'sbcj', 'sbdd', 'sbde', 'sbeb', 'sbed', 'sbee', 'sbef', 'sbeg', 'sbfa', 'sbfb', 'sbfe', 'sbff', 'sbga', 'sbge', 'sbgf', 'sbgg', 'sbgi', 'sbgj', 'sbhb', 'sbhc', 'sbhd', 'sbhe', 'sbhf', 'sbhg', 'sbhh', 'sbhi', 'sbia', 'sbid', 'sbie', 'sbif', 'sbig', 'sbih', 'sbij', 'sbjd', 'sbjf'], working_on=0, locked=False)]
# {'sa': 1, 'sb': 1, 'sc': 0, 'sd': 0, 'se': 0, 'sf': 0, 'sg': 1, 'sh': 0, 'si': 1, 'sj': 1, 'sba': 0, 'sbb': 1, 'sbc': 1, 'sbd': 0, 'sbe': 1, 'sbf': 1, 'sbg': 0, 'sbh': 0, 'sbi': 0, 'sbj': 0, 'sca': 0, 'scb': 1, 'scc': 0, 'scd': 1, 'sce': 0, 'scf': 1, 'scg': 0, 'sch': 0, 'sci': 0, 'scj': 0, 'sda': 1, 'sdb': 1, 'sdc': 0, 'sdd': 0, 'sde': 1, 'sdf': 0, 'sdg': 0, 'sdh': 1, 'sdi': 1, 'sdj': 1, 'sea': 0, 'seb': 0, 'sec': 1, 'sed': 0, 'see': 0, 'sef': 0, 'seg': 0, 'seh': 1, 'sei': 1, 'sej': 1, 'sfa': 0, 'sfb': 1, 'sfc': 0, 'sfd': 1, 'sfe': 1, 'sff': 1, 'sfg': 1, 'sfh': 1, 'sfi': 1, 'sfj': 1, 'sga': 1, 'sgb': 0, 'sgc': 1, 'sgd': 1, 'sge': 1, 'sgf': 0, 'sgg': 1, 'sgh': 1, 'sgi': 1, 'sgj': 0, 'sha': 0, 'shb': 0, 'shc': 0, 'shd': 0, 'she': 0, 'shf': 1, 'shg': 1, 'shh': 0, 'shi': 0, 'shj': 0, 'sia': 0, 'sib': 1, 'sic': 1, 'sid': 0, 'sie': 1, 'sif': 1, 'sig': 0, 'sih': 0, 'sii': 0, 'sij': 0, 'sja': 0, 'sjb': 0, 'sjc': 1, 'sjd': 0, 'sje': 1, 'sjf': 1, 'sjg': 1, 'sjh': 1, 'sji': 1, 'sjj': 1, 'sbaa': 0, 'sbab': 0, 'sbac': 1, 'sbad': 0, 'sbae': 0, 'sbaf': 0, 'sbag': 1, 'sbah': 1, 'sbai': 1, 'sbaj': 1, 'sbba': 1, 'sbbb': 0, 'sbbc': 1, 'sbbd': 1, 'sbbe': 0, 'sbbf': 1, 'sbbg': 0, 'sbbh': 1, 'sbbi': 1, 'sbbj': 1, 'sbca': 0, 'sbcb': 0, 'sbcc': 1, 'sbcd': 1, 'sbce': 1, 'sbcf': 1, 'sbcg': 0, 'sbch': 0, 'sbci': 0, 'sbcj': 1, 'sbda': 0, 'sbdb': 0, 'sbdc': 0, 'sbdd': 1, 'sbde': 1, 'sbdf': 0, 'sbdg': 0, 'sbdh': 0, 'sbdi': 0, 'sbdj': 0, 'sbea': 0, 'sbeb': 1, 'sbec': 0, 'sbed': 1, 'sbee': 1, 'sbef': 1, 'sbeg': 1, 'sbeh': 0, 'sbei': 0, 'sbej': 0, 'sbfa': 1, 'sbfb': 1, 'sbfc': 0, 'sbfd': 0, 'sbfe': 1, 'sbff': 1, 'sbfg': 0, 'sbfh': 0, 'sbfi': 0, 'sbfj': 0, 'sbga': 1, 'sbgb': 0, 'sbgc': 0, 'sbgd': 0, 'sbge': 1, 'sbgf': 1, 'sbgg': 1, 'sbgh': 0, 'sbgi': 1, 'sbgj': 1, 'sbha': 0, 'sbhb': 1, 'sbhc': 1, 'sbhd': 1, 'sbhe': 1, 'sbhf': 1, 'sbhg': 1, 'sbhh': 1, 'sbhi': 1, 'sbhj': 0, 'sbia': 1, 'sbib': 0, 'sbic': 0, 'sbid': 1, 'sbie': 1, 'sbif': 1, 'sbig': 1, 'sbih': 1, 'sbii': 0, 'sbij': 1, 'sbja': 0, 'sbjb': 0, 'sbjc': 0, 'sbjd': 1, 'sbje': 0, 'sbjf': 1, 'sbjg': 0, 'sbjh': 0, 'sbji': 0, 'sbjj': 0}
# [Feature(idx=0, name='sebbaaif', difficulty=9, users=547, dep_services=[['sbe', False], ['sei', False]], completed=False, binaries={1}), Feature(idx=1, name='sbcjiie', difficulty=42, users=197, dep_services=[['sg', False], ['shj', False], ['sf', False]], completed=False, binaries={0, 1}), Feature(idx=2, name='sbcdadcj', difficulty=6, users=422, dep_services=[['sej', False], ['sgi', False], ['seh', False], ['sge', False]], completed=False, binaries={1}), Feature(idx=3, name='siabdjfc', difficulty=40, users=746, dep_services=[['shi', False], ['sa', False], ['shd', False], ['sch', False]], completed=False, binaries={0, 1}), Feature(idx=4, name='shghjbi', difficulty=87, users=900, dep_services=[['sjh', False], ['sib', False]], completed=False, binaries={1}), Feature(idx=5, name='sgeaicfb', difficulty=39, users=560, dep_services=[['scb', False], ['shf', False], ['sfc', False]], completed=False, binaries={0, 1}), Feature(idx=6, name='scafbfej', difficulty=84, users=792, dep_services=[['sfc', False], ['sbh', False], ['sic', False]], completed=False, binaries={0, 1}), Feature(idx=7, name='sfifhbfe', difficulty=77, users=694, dep_services=[['sjc', False], ['sei', False], ['sc', False], ['sa', False]], completed=False, binaries={0, 1}), Feature(idx=8, name='sdejfiie', difficulty=73, users=554, dep_services=[['sde', False]], completed=False, binaries={1}), Feature(idx=9, name='sejcjbjf', difficulty=94, users=359, dep_services=[['shj', False], ['sjh', False], ['sdi', False]], completed=False, binaries={0, 1}), Feature(idx=10, name='sccihe', difficulty=80, users=303, dep_services=[['sce', False], ['sje', False], ['sgh', False], ['sde', False]], completed=False, binaries={0, 1}), Feature(idx=11, name='secghiej', difficulty=65, users=610, dep_services=[['shh', False], ['sbf', False], ['sh', False]], completed=False, binaries={0, 1}), Feature(idx=12, name='sejjjdhh', difficulty=34, users=343, dep_services=[['si', False], ['sbc', False], ['sca', False], ['seg', False]], completed=False, binaries={0, 1}), Feature(idx=13, name='scbgehaj', difficulty=37, users=363, dep_services=[['sdc', False], ['sca', False], ['sgc', False]], completed=False, binaries={0, 1}), Feature(idx=14, name='sgfeaeej', difficulty=15, users=970, dep_services=[['sjd', False], ['sgh', False]], completed=False, binaries={0, 1}), Feature(idx=15, name='seeecgii', difficulty=58, users=786, dep_services=[['shh', False], ['sij', False], ['sc', False], ['sif', False]], completed=False, binaries={0, 1}), Feature(idx=16, name='sdggidfg', difficulty=19, users=613, dep_services=[['sfc', False], ['sb', False], ['sie', False], ['sfj', False]], completed=False, binaries={0, 1}), Feature(idx=17, name='scdbgfjf', difficulty=83, users=989, dep_services=[['si', False], ['sij', False]], completed=False, binaries={0, 1}), Feature(idx=18, name='scfeajd', difficulty=94, users=515, dep_services=[['sbb', False], ['seh', False]], completed=False, binaries={1}), Feature(idx=19, name='siaejggb', difficulty=90, users=515, dep_services=[['sba', False], ['sbf', False]], completed=False, binaries={0, 1}), Feature(idx=20, name='sibebcbb', difficulty=20, users=593, dep_services=[['sdf', False], ['sda', False], ['sha', False]], completed=False, binaries={0, 1}), Feature(idx=21, name='seefabdg', difficulty=44, users=291, dep_services=[['sjh', False]], completed=False, binaries={1}), Feature(idx=22, name='sbbciefa', difficulty=64, users=990, dep_services=[['sii', False], ['sej', False]], completed=False, binaries={0, 1}), Feature(idx=23, name='sebijjdf', difficulty=48, users=402, dep_services=[['sgi', False], ['sjb', False], ['sbe', False], ['sfh', False]], completed=False, binaries={0, 1}), Feature(idx=24, name='secafejg', difficulty=13, users=718, dep_services=[['si', False], ['sed', False], ['shi', False]], completed=False, binaries={0, 1}), Feature(idx=25, name='sgdhijej', difficulty=14, users=378, dep_services=[['sge', False], ['sia', False]], completed=False, binaries={0, 1}), Feature(idx=26, name='shhej ...
# [Service(name='sa', binary=1, impl_features=[]), Service(name='sb', binary=1, impl_features=[]), Service(name='sc', binary=0, impl_features=[]), Service(name='sd', binary=0, impl_features=[]), Service(name='se', binary=0, impl_features=[]), Service(name='sf', binary=0, impl_features=[]), Service(name='sg', binary=1, impl_features=[]), Service(name='sh', binary=0, impl_features=[]), Service(name='si', binary=1, impl_features=[]), Service(name='sj', binary=1, impl_features=[]), Service(name='sba', binary=0, impl_features=[]), Service(name='sbb', binary=1, impl_features=[]), Service(name='sbc', binary=1, impl_features=[]), Service(name='sbd', binary=0, impl_features=[]), Service(name='sbe', binary=1, impl_features=[]), Service(name='sbf', binary=1, impl_features=[]), Service(name='sbg', binary=0, impl_features=[]), Service(name='sbh', binary=0, impl_features=[]), Service(name='sbi', binary=0, impl_features=[]), Service(name='sbj', binary=0, impl_features=[]), Service(name='sca', binary=0, impl_features=[]), Service(name='scb', binary=1, impl_features=[]), Service(name='scc', binary=0, impl_features=[]), Service(name='scd', binary=1, impl_features=[]), Service(name='sce', binary=0, impl_features=[]), Service(name='scf', binary=1, impl_features=[]), Service(name='scg', binary=0, impl_features=[]), Service(name='sch', binary=0, impl_features=[]), Service(name='sci', binary=0, impl_features=[]), Service(name='scj', binary=0, impl_features=[]), Service(name='sda', binary=1, impl_features=[]), Service(name='sdb', binary=1, impl_features=[]), Service(name='sdc', binary=0, impl_features=[]), Service(name='sdd', binary=0, impl_features=[]), Service(name='sde', binary=1, impl_features=[]), Service(name='sdf', binary=0, impl_features=[]), Service(name='sdg', binary=0, impl_features=[]), Service(name='sdh', binary=1, impl_features=[]), Service(name='sdi', binary=1, impl_features=[]), Service(name='sdj', binary=1, impl_features=[]), Service(name='sea', binary=0, impl_features=[]), Service(name='seb', binary=0, impl_features=[]), Service(name='sec', binary=1, impl_features=[]), Service(name='sed', binary=0, impl_features=[]), Service(name='see', binary=0, impl_features=[]), Service(name='sef', binary=0, impl_features=[]), Service(name='seg', binary=0, impl_features=[]), Service(name='seh', binary=1, impl_features=[]), Service(name='sei', binary=1, impl_features=[]), Service(name='sej', binary=1, impl_features=[]), Service(name='sfa', binary=0, impl_features=[]), Service(name='sfb', binary=1, impl_features=[]), Service(name='sfc', binary=0, impl_features=[]), Service(name='sfd', binary=1, impl_features=[]), Service(name='sfe', binary=1, impl_features=[]), Service(name='sff', binary=1, impl_features=[]), Service(name='sfg', binary=1, impl_features=[]), Service(name='sfh', binary=1, impl_features=[]), Service(name='sfi', binary=1, impl_features=[]), Service(name='sfj', binary=1, impl_features=[]), Service(name='sga', binary=1, impl_features=[]), Service(name='sgb', binary=0, impl_features=[]), Service(name='sgc', binary=1, impl_features=[]), Service(name='sgd', binary=1, impl_features=[]), Service(name='sge', binary=1, impl_features=[]), Service(name='sgf', binary=0, impl_features=[]), Service(name='sgg', binary=1, impl_features=[]), Service(name='sgh', binary=1, impl_features=[]), Service(name='sgi', binary=1, impl_features=[]), Service(name='sgj', binary=0, impl_features=[]), Service(name='sha', binary=0, impl_features=[]), Service(name='shb', binary=0, impl_features=[]), Service(name='shc', binary=0, impl_features=[]), Service(name='shd', binary=0, impl_features=[]), Service(name='she', binary=0, impl_features=[]), Service(name='shf', binary=1, impl_features=[]), Service(name='shg', binary=1, impl_features=[]), Service(name='shh', binary=0, impl_features=[]), Service(name='shi', binary=0, impl_features=[]), Service(name='shj', binary=0, impl_features=[]), Service(name='sia', binary=0, impl_features=[]), Service(name='sib', binary=1, impl_featu ...

# %% [markdown]
# ## Attività
# Di seguito sono illustrate le mosse che un ingegnere può effettuare.
#
# Ciascuna mossa è caratterizzata da una durata. Per ogni mossa è definita una procedura per eseguirla sui dati di input. Ogni procedura ha la seguente firma:
# * input:
#     * ingegnere su cui schedulare l'attività;
#     * giorno in cui effettuare l'attività;
#     * feature, binary, service su cui effettuare l'attività;
# * output:
#     * durata dell'attività;

# %% [markdown]
# ### Implementazione di una nuova feature
# Su un *binary* $B_j$ può un ingegnere implementare tutti i servizi per una feature $F_i$. Questa mossa ha una durata $D_{Fi} + R_{Bj} + C_{Bj}$. Dove $D_{Fi}$ è data dalla complessità della **Feature**, $R_{Bj}$ è dato dal numero di servizi totali presenti nel *binary*, $C_{Bj}$ ingegneri che stanno già lavorando su $B_j$ nel giorno in cui viene *schedulata* l'attività. Inoltre, ogni ingegnere può implementare la stessa **Feature** su **binary** diversi. Infine, se più ingegneri sono *schedulati* per lavorare sullo stesso **binary** il primo della soluzione viene schedulato e conta per gli altri nel fattore $C_{Bj}$;

# %%
def implement_feature(e: Engineer, day: int, f: int, b: int) -> int:
    assert(b >= 0 and b < B)
    assert(day >=0 and day < L)
    assert(f >= 0 and f < F)
    global score
    feature = features[f]
    
    duration  = feature.difficulty + len(binaries[b].services) + binaries[b].working_on
    for service in feature.dep_services:
        s_name = service[0]
        done = service[1]
        if service_to_binaries[s_name] == b and not done:
            service[1] = True
    
    for (service, done) in feature.dep_services:
        if not done:
            break
    else:
        if not feature.completed:
            feature.completed = True
            # print("DEBUG: completed", feature, "multiply", 1 if  L-(day + duration) >= 0 else 0  )
            # print("DEBUG: remaining", len(features))
            score += feature.users * max(0, L-(day + duration)) 
    e.add_op("impl", day, duration, [f, b])
    daily_schedule.append((day + duration, b))
    binaries[b].working_on+=1
    
    return duration

# %% [markdown]
# ### Migrazione di un service
# un ingegnere può spostare un servizio $S_i$ da un *binary* $B_j$ a $B_k$, mantenendo le funzionalità implementate. Per fare questa mossa, un ingegnere impiega $\max (R_{bj}, R_{bk})$ giorni dove $R_{bj}, R_{bk}$ sono i servizi in esecuzione rispettivamente su $B_j$ a $B_k$. Quest'azione però è bloccante: nessun ingegnere può lavorare su $B_j$ e $B_k$ quando è in corso una migrazione;

# %%
def move_service(e: Engineer, day: int, s: int, dst: int) -> int:
    assert(service_to_binaries[s] != dst)
    assert(day >= 0 and  day < L)
    assert(dst >= 0 and dst < B)
    service = services[s]
    src = service.binary
    duration  = max(len(binaries[src].services), len(binaries[dst].services))
    service_to_binaries[service.name] = dst
    binaries[src].services.remove(s)
    binaries[dst].services.append(s)
    binaries[src].locked = True
    binaries[dst].locked = True
    e.add_op("move", day, duration, [service.name, src, dst])
    return duration

# %% [markdown]
# ### Nuovo binary
# Un ingegnere può creare un nuovo binary senza nessun servizio al suo interno. Il costo per creare è un nuovo binary è fisso e vale $N$.

# %%
def new_binary(e: Engineer, day: int)-> int:
    assert(day >=0 and day < L)
    binaries.append(Binary(len(binaries)))
    e.add_op("new", day, N, [])
    return N

# %% [markdown]
# ### Idle
# Un ingegnere può essere in idle per un numero di giorni $1\leq W \leq L$

# %%
def wait(e: Engineer, day: int, duration: int) -> int:
    assert(day >=0 and day < L)
    e.add_op("wait", day, duration, [])
    return 1

# %% [markdown]
# ## Euristica
# In una fase preliminare, l'algoritmo ordina le feature per numero di utenti soddisfatti. In questo approccio, si assegna un punteggio maggiore ai servizi che risiedono sulla stessa macchina.

# %%
features.sort(key=lambda x: (x.users-10*x.difficulty)/len(x.binaries), reverse=True)
# print(features[:10])

for day in range(L):
    while len(daily_schedule) > 0 and daily_schedule[-1][0] <= day:
        # migrazione
        if len(daily_schedule[-1]) == 3:
            b1 = daily_schedule[-1][1]
            b2 = daily_schedule[-1][2]
            binaries[b1].locked = False 
            binaries[b2].locked = False 
        elif len(daily_schedule[-1]) == 2:
            bid: int = daily_schedule[-1][1] 
            binaries[bid].working_on -=1
        else:
            raise Exception("unknown schedule event", daily_schedule[-1])
        daily_schedule.pop()
    
    current = 0
    for engineer in engineers:
        if engineer.avail <= day:
            completed = [k for k in features if k.completed]
            if len(completed) == len(features):
                break
            f: Feature = features[current]
            # print("doing", f)

            for bin in f.binaries:
                # next_b = service_to_binaries[dep[0]]
                # if next_b != b and not dep[1]:
                    implement_feature(engineer, day, current, bin)
                    if f.completed:
                        current += 1
                        break
           

num_eng: int = len([engineer for engineer in engineers if len(engineer.ops) > 0])
print(num_eng)
for engineer in engineers:
    if len(engineer.ops) == 0:
        continue
    print(engineer.id)
    for op in engineer.ops:
        print(op[0], end=" ")
        if op[0] == "impl":
            f = features[op[1][0]]
            print(f.name, op[1][1])
        elif op[0] == "move":
            print(op[1][0], op[1][2])
        elif op[0] == "wait":
            print(op[0], op[1][0])

print(score)
# print("features", features)
# print("impl features:", impl_features)
# sus = [f.users for f in impl_features]
# print(sum(sus))
# record 158.421.404
# Out:
# 100
# 0
# impl seacajee 1
# 1
# impl sihaaddd 1
# 2
# impl sebbaaif 1
# 3
# impl sihbfedi 0
# impl sihbfedi 1
# 4
# impl sbbcchfb 0
# 5
# impl sgfeaeej 0
# impl sgfeaeej 1
# 6
# impl sgfaddad 0
# impl sgfaddad 1
# 7
# impl sbcdadcj 1
# 8
# impl shhejdab 0
# 9
# impl sejcbdfe 0
# 10
# impl secafejg 0
# impl secafejg 1
# 11
# impl sdaeabdf 1
# 12
# impl sgfbafdh 0
# impl sgfbafdh 1
# 13
# impl sbcadbij 0
# impl sbcadbij 1
# 14
# impl sfgefcfh 0
# impl sfgefcfh 1
# 15
# impl shfdhehd 0
# 16
# impl sbcbhiaa 0
# impl sbcbhiaa 1
# 17
# impl sdggidfg 0
# impl sdggidfg 1
# 18
# impl sibjccge 0
# 19
# impl sibebcbb 0
# impl sibebcbb 1
# 20
# impl sgffhfgb 0
# impl sgffhfgb 1
# 21
# impl sedefdjc 1
# 22
# impl sbbciefa 0
# impl sbbciefa 1
# 23
# impl siabdjfc 0
# impl siabdjfc 1
# 24
# impl sgdhijej 0
# impl sgdhijej 1
# 25
# impl sjbccicc 0
# impl sjbccicc 1
# 26
# impl seeecgii 0
# impl seeecgii 1
# 27
# impl scbheecj 0
# impl scbheecj 1
# 28
# impl shacfcbd 0
# impl shacfcbd 1
# 29
# impl sehbaiga 0
# impl sehbaiga 1
# 30
# impl sdcgjcbf 0
# impl sdcgjcbf 1
# 31
# impl sgeaicfb 0
# impl sgeaicfb 1
# 32
# impl scjajghj 0
# 33
# impl sgcfbd 0
# impl sgcfbd 1
# 34
# impl sbibhdeh 1
# 35
# impl scdbgfjf 0
# impl scdbgfjf 1
# 36
# impl sjcbhigg 1
# 37
# impl sgbjjahf 0
# impl sgbjjahf 1
# 38
# impl sjhfebca 0
# impl sjhfebca 1
# 39
# impl sddbejje 0
# impl sddbejje 1
# 40
# impl shghjbi 1
# 41
# impl scjighfg 0
# impl scjighfg 1
# 42
# impl sejjjdhh 0
# impl sejjjdhh 1
# 43
# impl scbgehaj 0
# impl scbgehaj 1
# 44
# impl sjeijjdf 0
# impl sjeijjdf 1
# 45
# impl sdeechcc 0
# impl sdeechcc 1
# 46
# impl shgjcdec 0
# impl shgjcdec 1
# 47
# impl secghiej 0
# impl secghiej 1
# 48
# impl scafbfej 0
# impl scafbfej 1
# 49
# impl sfifhbfe 0
# impl sfifhbfe 1
# 50
# impl sebijjdf 0
# impl sebijjdf 1
# 51
# impl sfacfggi 0
# impl sfacfggi 1
# 52
# impl sjhiedfb 0
# impl sjhiedfb 1
# 53
# impl sjjcccia 0
# impl sjjcccia 1
# 54
# impl sbfahjej 0
# impl sbfahjej 1
# 55
# impl secgbdah 0
# impl secgbdah 1
# 56
# impl sbciihba 0
# impl sbciihba 1
# 57
# impl sjecbaeh 0
# impl sjecbaeh 1
# 58
# impl sigjbbj 0
# impl sigjbbj 1
# 59
# impl siicjdcg 0
# impl siicjdcg 1
# 60
# impl scibehej 0
# impl scibehej 1
# 61
# impl sgijcebi 0
# 62
# impl scicgaji 1
# 63
# impl scjgafg 0
# impl scjgafg 1
# 64
# impl sbcjiie 0
# impl sbcjiie 1
# 65
# impl scgjjhbh 0
# impl scgjjhbh 1
# 66
# impl sieafdid 0
# impl sieafdid 1
# 67
# impl sidcbdcg 1
# 68
# impl sjgbcffd 0
# impl sjgbcffd 1
# 69
# impl seefabdg 1
# 70
# impl sfgiigee 1
# 71
# impl sgeihiic 0
# impl sgeihiic 1
# 72
# impl sdjaeafb 1
# 73
# impl sdejfiie 1
# 74
# impl shgbegij 0
# impl shgbegij 1
# 75
# impl siaejggb 0
# impl siaejggb 1
# 76
# impl sgbbdeii 0
# impl sgbbdeii 1
# 77
# impl segghbga 0
# impl segghbga 1
# 78
# impl sheegbcg 0
# impl sheegbcg 1
# 79
# impl sccihe 0
# impl sccihe 1
# 80
# impl seebgedb 0
# 81
# impl shddfeih 0
# impl shddfeih 1
# 82
# impl seafeafb 0
# 83
# impl shicfiag 0
# impl shicfiag 1
# 84
# impl sejcjbjf 0
# impl sejcjbjf 1
# 85
# impl shbjhaeh 0
# impl shbjhaeh 1
# 86
# impl sgbfdcdc 0
# 87
# impl sighiagc 0
# impl sighiagc 1
# 88
# impl secfjgaa 0
# 89
# impl sibajfgd 0
# impl sibajfgd 1
# 90
# impl sdehjghc 0
# impl sdehjghc 1
# 91
# impl sbjafeib 0
# impl sbjafeib 1
# 92
# impl seicdjjf 0
# impl seicdjjf 1
# 93
# impl sbjejgjj 0
# impl sbjejgjj 1
# 94
# impl scfeajd 1
# 95
# impl segcagid 0
# impl segcagid 1
# 96
# impl scfjjdjg 0
# 97
# impl sgjcibef 1
# 98
# impl sdfehjjh 1
# 99
# impl sfdgggfe 0
# 35559607
